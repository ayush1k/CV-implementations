# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# 1. Download the dataset archive quietly
# !wget -q https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz

# 2. Untar the archive directly into Kaggle's working directory
# !tar -xzf flower_photos.tgz -C /kaggle/working/

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torchvision.models import squeezenet1_1, SqueezeNet1_1_Weights
from torch.utils.data import DataLoader, random_split
import os

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 0.001
INPUT_SIZE = 224

# Set compute device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Primary compute device: {device}")
# Out:
# Primary compute device: cuda

# %%
# Define separate transformation pipelines for Training and Validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.RandomHorizontalFlip(),  # Augmentation to prevent overfitting
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# 1. Load full raw dataset
data_dir = "/kaggle/working/flower_photos"
full_dataset = datasets.ImageFolder(root=data_dir, transform=data_transforms['train'])

# %%
# 2. Perform 80/20 train/validation split
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# %%
# 3. Override validation subset transform so validation images aren't randomly flipped
val_dataset.dataset.transform = data_transforms['val']

# %%
# 4. Construct DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
print(f"Training set: {len(train_dataset)} images | Validation set: {len(val_dataset)} images")
# Out:
# Training set: 2936 images | Validation set: 734 images

# %%
from torchvision.models import resnet50, ResNet50_Weights

# 1. Load pretrained ResNet50
model = resnet50(weights=ResNet50_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 148MB/s]

# %%
# 2. Freeze all foundational layers
for param in model.parameters():
    param.requires_grad = False

# %%
# 3. Modify ResNet50's final classification layer
# ResNet's final layer is 'fc', which expects 2048 input features
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 5)

# %%
# 4. Unfreeze parameters for ONLY the new classification layer
for param in model.fc.parameters():
    param.requires_grad = True

# %%
# 5. Enable Multi-GPU training across both Kaggle T4 GPUs
if torch.cuda.device_count() > 1:
    print(f"Detected {torch.cuda.device_count()} GPUs! Wrapping model in DataParallel...")
    model = nn.DataParallel(model)
# Out:
# Detected 2 GPUs! Wrapping model in DataParallel...

# %%
# Move the model to GPU memory
model = model.to(device)

# %%
# 6. Define Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, epochs):
    # Local history dictionary to log metrics
    history = {'train_loss': [], 'train_acc': [], 'val_acc': []}
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        print("-" * 30)
        
        # ================= TRAINING PHASE =================
        model.train()  # Enables Dropout layers in training mode
        train_correct = 0
        train_total = 0
        running_loss = 0.0

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()            # Clear old gradients
            outputs = model(images)          # Forward pass
            loss = criterion(outputs, labels) # Calculate Cross-Entropy Loss
            loss.backward()                  # Backward pass (compute gradients)
            optimizer.step()                 # Update layer weights

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1) # Extract class prediction with highest logit
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            # Print status every 20 batches
            if (i + 1) % 20 == 0:
                batch_acc = (preds == labels).sum().item() / labels.size(0)
                print(f"[Batch {i+1}/{len(train_loader)}] Loss: {loss.item():.4f} | Batch Acc: {batch_acc:.4f}")

        train_acc = train_correct / train_total
        avg_train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1} Summary - Train Loss: {avg_train_loss:.4f} | Train Acc: {train_acc:.4f}")

        # ================= VALIDATION PHASE =================
        model.eval()  # Disables Dropout for evaluation
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():  # Disable gradient calculation to conserve VRAM
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total
        print(f"Validation Accuracy: {val_acc:.4f}")
        
        # Save metrics locally
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        
    return history

# %%
# Execute training
history = train_model(model, criterion, optimizer, train_loader, val_loader, epochs=EPOCHS)
# Out:
# Epoch 1/50
# ------------------------------
# [Batch 20/92] Loss: 1.2258 | Batch Acc: 0.4688
# [Batch 40/92] Loss: 0.8526 | Batch Acc: 0.8125
# [Batch 60/92] Loss: 0.5777 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.6812 | Batch Acc: 0.8125
# Epoch 1 Summary - Train Loss: 0.8724 | Train Acc: 0.7606
# Validation Accuracy: 0.8719
#
# Epoch 2/50
# ------------------------------
# [Batch 20/92] Loss: 0.4759 | Batch Acc: 0.8438
# [Batch 40/92] Loss: 0.5688 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.3849 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.8104 | Batch Acc: 0.7188
# Epoch 2 Summary - Train Loss: 0.4569 | Train Acc: 0.8896
# Validation Accuracy: 0.8965
#
# Epoch 3/50
# ------------------------------
# [Batch 20/92] Loss: 0.4363 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.2966 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2531 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.2909 | Batch Acc: 0.9375
# Epoch 3 Summary - Train Loss: 0.3552 | Train Acc: 0.9074
# Validation Accuracy: 0.8937
#
# Epoch 4/50
# ------------------------------
# [Batch 20/92] Loss: 0.4020 | Batch Acc: 0.8125
# [Batch 40/92] Loss: 0.2494 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.2534 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2753 | Batch Acc: 0.9375
# Epoch 4 Summary - Train Loss: 0.3087 | Train Acc: 0.9162
# Validation Accuracy: 0.9101
#
# Epoch 5/50
# ------------------------------
# [Batch 20/92] Loss: 0.3822 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.1415 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1999 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2196 | Batch Acc: 0.9688
# Epoch 5 Summary - Train Loss: 0.2660 | Train Acc: 0.9302
# Validation Accuracy: 0.9074
#
# Epoch 6/50
# ------------------------------
# [Batch 20/92] Loss: 0.2421 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.4209 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.1846 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1518 | Batch Acc: 0.9375
# Epoch 6 Summary - Train Loss: 0.2323 | Train Acc: 0.9370
# Validation Accuracy: 0.9114
#
# Epoch 7/50
# ------------------------------
# [Batch 20/92] Loss: 0.3462 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1464 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1615 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.2490 | Batch Acc: 0.9375
# Epoch 7 Summary - Train Loss: 0.2162 | Train Acc: 0.9465
# Validation Accuracy: 0.9155
#
# Epoch 8/50
# ------------------------------
# [Batch 20/92] Loss: 0.1472 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.3522 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.2067 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.3104 | Batch Acc: 0.8125
# Epoch 8 Summary - Train Loss: 0.1953 | Train Acc: 0.9479
# Validation Accuracy: 0.9196
#
# Epoch 9/50
# ------------------------------
# [Batch 20/92] Loss: 0.2636 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.1702 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2035 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0772 | Batch Acc: 1.0000
# Epoch 9 Summary - Train Loss: 0.1887 | Train Acc: 0.9506
# Validation Accuracy: 0.9155
#
# Epoch 10/50
# ------------------------------
# [Batch 20/92] Loss: 0.1160 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2360 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2623 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0675 | Batch Acc: 1.0000
# Epoch 10 Summary - Train Loss: 0.1714 | Train Acc: 0.9557
# Validation Accuracy: 0.9210
#
# Epoch 11/50
# ------------------------------
# [Batch 20/92] Loss: 0.1211 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0642 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1490 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1735 | Batch Acc: 0.9375
# Epoch 11 Summary - Train Loss: 0.1587 | Train Acc: 0.9608
# Validation Accuracy: 0.9210
#
# Epoch 12/50
# ------------------------------
# [Batch 20/92] Loss: 0.1536 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1339 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.3380 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1305 | Batch Acc: 0.9375
# Epoch 12 Summary - Train Loss: 0.1574 | Train Acc: 0.9584
# Validation Accuracy: 0.9196
#
# Epoch 13/50
# ------------------------------
# [Batch 20/92] Loss: 0.1525 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1397 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1138 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1504 | Batch Acc: 0.9688
# Epoch 13 Summary - Train Loss: 0.1407 | Train Acc: 0.9649
# Validation Accuracy: 0.9237
#
# Epoch 14/50
# ------------------------------
# [Batch 20/92] Loss: 0.0747 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1195 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0969 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0992 | Batch Acc: 1.0000
# Epoch 14 Summary - Train Loss: 0.1316 | Train Acc: 0.9700
# Validation Accuracy: 0.9264
#
# Epoch 15/50
# ------------------------------
# [Batch 20/92] Loss: 0.1019 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0338 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1059 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0996 | Batch Acc: 1.0000
# Epoch 15 Summary - Train Loss: 0.1302 | Train Acc: 0.9663
# Validation Accuracy: 0.9223
#
# Epoch 16/50
# ------------------------------
# [Batch 20/92] Loss: 0.1310 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2441 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1191 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0943 | Batch Acc: 1.0000
# Epoch 16 Summary - Train Loss: 0.1193 | Train Acc: 0.9738
# Validation Accuracy: 0.9264
#
# Epoch 17/50
# ------------------------------
# [Batch 20/92] Loss: 0.1283 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0586 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2049 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1014 | Batch Acc: 0.9688
# Epoch 17 Summary - Train Loss: 0.1178 | Train Acc: 0.9721
# Validation Accuracy: 0.9169
#
# Epoch 18/50
# ------------------------------
# [Batch 20/92] Loss: 0.0904 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0930 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0474 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1253 | Batch Acc: 0.9375
# Epoch 18 Summary - Train Loss: 0.1166 | Train Acc: 0.9721
# Validation Accuracy: 0.9196
#
# Epoch 19/50
# ------------------------------
# [Batch 20/92] Loss: 0.0613 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1287 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0895 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0643 | Batch Acc: 1.0000
# Epoch 19 Summary - Train Loss: 0.1197 | Train Acc: 0.9738
# Validation Accuracy: 0.9196
#
# Epoch 20/50
# ------------------------------
# [Batch 20/92] Loss: 0.0804 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1267 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1387 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1076 | Batch Acc: 0.9688
# Epoch 20 Summary - Train Loss: 0.1132 | Train Acc: 0.9738
# Validation Accuracy: 0.9223
#
# Epoch 21/50
# ------------------------------
# [Batch 20/92] Loss: 0.1564 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1647 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1661 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0706 | Batch Acc: 1.0000
# Epoch 21 Summary - Train Loss: 0.0961 | Train Acc: 0.9813
# Validation Accuracy: 0.9196
#
# Epoch 22/50
# ------------------------------
# [Batch 20/92] Loss: 0.0519 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1068 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2103 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.0419 | Batch Acc: 1.0000
# Epoch 22 Summary - Train Loss: 0.0925 | Train Acc: 0.9819
# Validation Accuracy: 0.9210
#
# Epoch 23/50
# ------------------------------
# [Batch 20/92] Loss: 0.0765 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1084 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0908 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0364 | Batch Acc: 1.0000
# Epoch 23 Summary - Train Loss: 0.0908 | Train Acc: 0.9806
# Validation Accuracy: 0.9237
#
# Epoch 24/50
# ------------------------------
# [Batch 20/92] Loss: 0.0939 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0871 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1218 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0502 | Batch Acc: 1.0000
# Epoch 24 Summary - Train Loss: 0.0843 | Train Acc: 0.9823
# Validation Accuracy: 0.9223
#
# Epoch 25/50
# ------------------------------
# [Batch 20/92] Loss: 0.1112 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1050 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0445 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0751 | Batch Acc: 1.0000
# Epoch 25 Summary - Train Loss: 0.0906 | Train Acc: 0.9816
# Validation Accuracy: 0.9155
#
# Epoch 26/50
# ------------------------------
# [Batch 20/92] Loss: 0.1259 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0754 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0430 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1372 | Batch Acc: 0.9688
# Epoch 26 Summary - Train Loss: 0.0835 | Train Acc: 0.9830
# Validation Accuracy: 0.9292
#
# Epoch 27/50
# ------------------------------
# [Batch 20/92] Loss: 0.0541 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1118 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0961 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0641 | Batch Acc: 1.0000
# Epoch 27 Summary - Train Loss: 0.0849 | Train Acc: 0.9802
# Validation Accuracy: 0.9169
#
# Epoch 28/50
# ------------------------------
# [Batch 20/92] Loss: 0.0657 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0818 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0303 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0562 | Batch Acc: 0.9688
# Epoch 28 Summary - Train Loss: 0.0724 | Train Acc: 0.9850
# Validation Accuracy: 0.9210
#
# Epoch 29/50
# ------------------------------
# [Batch 20/92] Loss: 0.0407 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0432 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0300 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0479 | Batch Acc: 0.9688
# Epoch 29 Summary - Train Loss: 0.0794 | Train Acc: 0.9809
# Validation Accuracy: 0.9183
#
# Epoch 30/50
# ------------------------------
# [Batch 20/92] Loss: 0.0603 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0131 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0424 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0674 | Batch Acc: 1.0000
# Epoch 30 Summary - Train Loss: 0.0758 | Train Acc: 0.9830
# Validation Accuracy: 0.9251
#
# Epoch 31/50
# ------------------------------
# [Batch 20/92] Loss: 0.0612 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0626 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0945 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2181 | Batch Acc: 0.9688
# Epoch 31 Summary - Train Loss: 0.0744 | Train Acc: 0.9823
# Validation Accuracy: 0.9251
#
# Epoch 32/50
# ------------------------------
# [Batch 20/92] Loss: 0.0798 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0737 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0730 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0587 | Batch Acc: 0.9688
# Epoch 32 Summary - Train Loss: 0.0655 | Train Acc: 0.9881
# Validation Accuracy: 0.9183
#
# Epoch 33/50
# ------------------------------
# [Batch 20/92] Loss: 0.0617 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0923 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0461 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0556 | Batch Acc: 1.0000
# Epoch 33 Summary - Train Loss: 0.0733 | Train Acc: 0.9837
# Validation Accuracy: 0.9237
#
# Epoch 34/50
# ------------------------------
# [Batch 20/92] Loss: 0.0327 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0811 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0634 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0601 | Batch Acc: 1.0000
# Epoch 34 Summary - Train Loss: 0.0646 | Train Acc: 0.9857
# Validation Accuracy: 0.9237
#
# Epoch 35/50
# ------------------------------
# [Batch 20/92] Loss: 0.0272 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0349 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0467 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0681 | Batch Acc: 0.9688
# Epoch 35 Summary - Train Loss: 0.0628 | Train Acc: 0.9877
# Validation Accuracy: 0.9210
#
# Epoch 36/50
# ------------------------------
# [Batch 20/92] Loss: 0.0798 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0453 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0866 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1306 | Batch Acc: 0.9375
# Epoch 36 Summary - Train Loss: 0.0630 | Train Acc: 0.9874
# Validation Accuracy: 0.9183
#
# Epoch 37/50
# ------------------------------
# [Batch 20/92] Loss: 0.0394 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0568 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0612 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0959 | Batch Acc: 0.9688
# Epoch 37 Summary - Train Loss: 0.0636 | Train Acc: 0.9843
# Validation Accuracy: 0.9142
#
# Epoch 38/50
# ------------------------------
# [Batch 20/92] Loss: 0.0761 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0229 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0652 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1312 | Batch Acc: 0.9375
# Epoch 38 Summary - Train Loss: 0.0674 | Train Acc: 0.9837
# Validation Accuracy: 0.9169
#
# Epoch 39/50
# ------------------------------
# [Batch 20/92] Loss: 0.0817 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0176 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0213 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1095 | Batch Acc: 0.9688
# Epoch 39 Summary - Train Loss: 0.0642 | Train Acc: 0.9837
# Validation Accuracy: 0.9251
#
# Epoch 40/50
# ------------------------------
# [Batch 20/92] Loss: 0.0191 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0282 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0373 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0959 | Batch Acc: 0.9688
# Epoch 40 Summary - Train Loss: 0.0628 | Train Acc: 0.9850
# Validation Accuracy: 0.9292
#
# Epoch 41/50
# ------------------------------
# [Batch 20/92] Loss: 0.0326 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0652 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1178 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0739 | Batch Acc: 1.0000
# Epoch 41 Summary - Train Loss: 0.0587 | Train Acc: 0.9871
# Validation Accuracy: 0.9183
#
# Epoch 42/50
# ------------------------------
# [Batch 20/92] Loss: 0.0187 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0574 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0607 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1034 | Batch Acc: 0.9688
# Epoch 42 Summary - Train Loss: 0.0557 | Train Acc: 0.9888
# Validation Accuracy: 0.9223
#
# Epoch 43/50
# ------------------------------
# [Batch 20/92] Loss: 0.0189 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0663 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1273 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0169 | Batch Acc: 1.0000
# Epoch 43 Summary - Train Loss: 0.0568 | Train Acc: 0.9850
# Validation Accuracy: 0.9196
#
# Epoch 44/50
# ------------------------------
# [Batch 20/92] Loss: 0.0391 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0107 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0180 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0190 | Batch Acc: 1.0000
# Epoch 44 Summary - Train Loss: 0.0468 | Train Acc: 0.9911
# Validation Accuracy: 0.9196
#
# Epoch 45/50
# ------------------------------
# [Batch 20/92] Loss: 0.0459 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0337 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0254 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0338 | Batch Acc: 1.0000
# Epoch 45 Summary - Train Loss: 0.0505 | Train Acc: 0.9894
# Validation Accuracy: 0.9278
#
# Epoch 46/50
# ------------------------------
# [Batch 20/92] Loss: 0.0654 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1337 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0431 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0231 | Batch Acc: 1.0000
# Epoch 46 Summary - Train Loss: 0.0465 | Train Acc: 0.9915
# Validation Accuracy: 0.9155
#
# Epoch 47/50
# ------------------------------
# [Batch 20/92] Loss: 0.0917 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0631 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0640 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0338 | Batch Acc: 1.0000
# Epoch 47 Summary - Train Loss: 0.0494 | Train Acc: 0.9911
# Validation Accuracy: 0.9305
#
# Epoch 48/50
# ------------------------------
# [Batch 20/92] Loss: 0.0262 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0517 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1594 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0467 | Batch Acc: 0.9688
# Epoch 48 Summary - Train Loss: 0.0521 | Train Acc: 0.9884
# Validation Accuracy: 0.9183
#
# Epoch 49/50
# ------------------------------
# [Batch 20/92] Loss: 0.0268 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0934 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0260 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0958 | Batch Acc: 0.9688
# Epoch 49 Summary - Train Loss: 0.0523 | Train Acc: 0.9884
# Validation Accuracy: 0.9196
#
# Epoch 50/50
# ------------------------------
# [Batch 20/92] Loss: 0.0297 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0188 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0382 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0226 | Batch Acc: 1.0000
# Epoch 50 Summary - Train Loss: 0.0450 | Train Acc: 0.9911
# Validation Accuracy: 0.9210

# %%
import matplotlib.pyplot as plt

# Set aesthetic style
plt.style.use('seaborn-v0_8-whitegrid')
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot Accuracy History
axes[0].plot(history['train_acc'], label='Train Accuracy', color='#1f77b4', linewidth=2)
axes[0].plot(history['val_acc'], label='Validation Accuracy', color='#ff7f0e', linewidth=2)
axes[0].set_title('SqueezeNet Accuracy over 50 Epochs', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot Loss History
axes[1].plot(history['train_loss'], label='Train Loss', color='#d62728', linewidth=2)
axes[1].set_title('SqueezeNet Loss over 50 Epochs', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save Model Checkpoint
save_path = '/kaggle/working/squeezenet_5flowers_model.pth'
torch.save(model.state_dict(), save_path)
print(f"Model weights successfully saved to {save_path}")
# Out:
# Model weights successfully saved to /kaggle/working/squeezenet_5flowers_model.pth

# %%
import random
import matplotlib.pyplot as plt

# 1. Retrieve the list of flower class names 
class_names = full_dataset.classes

# %%
# 2. Lock the model into evaluation mode
model.eval()
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=5, bias=True)
#   )
# )

# %%
# 3. Select a random image from the validation set
random_idx = random.randint(0, len(val_dataset) - 1)
image_tensor, actual_label_idx = val_dataset[random_idx]

# %%
# 4. Add a batch dimension: (C, H, W) -> (1, C, H, W) and move to GPU
image_batch = image_tensor.unsqueeze(0).to(device)

# %%
# 5. Perform the forward pass (inference)
with torch.no_grad():
    output = model(image_batch)
    # Extract the index of the highest logit score
    _, predicted_idx = torch.max(output, 1)

# %%
# Map the numerical indices back to the string names
actual_flower = class_names[actual_label_idx]
predicted_flower = class_names[predicted_idx.item()]

# %%
# 6. Un-normalize the image for human viewing
# Move tensor to CPU, then convert to a NumPy array
image_display = image_tensor.permute(1, 2, 0).cpu().numpy()

# %%
# Apply the inverse of the ImageNet normalization math
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
image_display = std * image_display + mean
image_display = image_display.clip(0, 1) # Force pixel values into valid [0, 1] range

# %%
# 7. Plot the result
plt.figure(figsize=(6, 6))
plt.imshow(image_display)

# Title is green if correct, red if the model made a mistake
title_color = "#2ca02c" if actual_flower == predicted_flower else "#d62728"
plt.title(f"Actual: {actual_flower} | Predicted: {predicted_flower}", color=title_color, fontsize=14, fontweight='bold')
plt.axis('off')
plt.show()
