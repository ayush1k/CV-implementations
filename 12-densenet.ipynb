# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# 1. Download the dataset archive quietly
# !wget -q https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz

# 2. Untar the archive directly into Kaggle's working directory
# !tar -xzf flower_photos.tgz -C /kaggle/working/

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import os

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 0.001
INPUT_SIZE = 224

# Set compute device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Primary compute device: {device}")
# Out:
# Primary compute device: cuda

# %%
# Define separate transformation pipelines for Training and Validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.RandomHorizontalFlip(),  # Augmentation to prevent overfitting
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# 1. Load full raw dataset
data_dir = "/kaggle/working/flower_photos"
full_dataset = datasets.ImageFolder(root=data_dir, transform=data_transforms['train'])

# %%
# 2. Perform 80/20 train/validation split
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# %%
# 3. Override validation subset transform so validation images aren't randomly flipped
val_dataset.dataset.transform = data_transforms['val']

# %%
# 4. Construct DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
print(f"Training set: {len(train_dataset)} images | Validation set: {len(val_dataset)} images")
# Out:
# Training set: 2936 images | Validation set: 734 images

# %%
from torchvision.models import densenet121, DenseNet121_Weights

# 1. Load pretrained DenseNet121
model = densenet121(weights=DenseNet121_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 233MB/s]

# %%
# 2. Freeze all foundational layers
for param in model.parameters():
    param.requires_grad = False

# %%
# 3. Modify DenseNet's final classification layer
# DenseNet's final layer is named 'classifier' and expects 1024 input features
num_ftrs = model.classifier.in_features
model.classifier = nn.Linear(num_ftrs, 5)

# %%
# 4. Unfreeze parameters for ONLY the new classification layer
for param in model.classifier.parameters():
    param.requires_grad = True

# %%
# 5. Enable Multi-GPU training across both Kaggle T4 GPUs
if torch.cuda.device_count() > 1:
    print(f"Detected {torch.cuda.device_count()} GPUs! Wrapping model in DataParallel...")
    model = nn.DataParallel(model)
# Out:
# Detected 2 GPUs! Wrapping model in DataParallel...

# %%
# Move the model to GPU memory
model = model.to(device)

# %%
# 6. Define Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, epochs):
    # Local history dictionary to log metrics
    history = {'train_loss': [], 'train_acc': [], 'val_acc': []}
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        print("-" * 30)
        
        # ================= TRAINING PHASE =================
        model.train()  # Enables Dropout layers in training mode
        train_correct = 0
        train_total = 0
        running_loss = 0.0

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()            # Clear old gradients
            outputs = model(images)          # Forward pass
            loss = criterion(outputs, labels) # Calculate Cross-Entropy Loss
            loss.backward()                  # Backward pass (compute gradients)
            optimizer.step()                 # Update layer weights

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1) # Extract class prediction with highest logit
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            # Print status every 20 batches
            if (i + 1) % 20 == 0:
                batch_acc = (preds == labels).sum().item() / labels.size(0)
                print(f"[Batch {i+1}/{len(train_loader)}] Loss: {loss.item():.4f} | Batch Acc: {batch_acc:.4f}")

        train_acc = train_correct / train_total
        avg_train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1} Summary - Train Loss: {avg_train_loss:.4f} | Train Acc: {train_acc:.4f}")

        # ================= VALIDATION PHASE =================
        model.eval()  # Disables Dropout for evaluation
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():  # Disable gradient calculation to conserve VRAM
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total
        print(f"Validation Accuracy: {val_acc:.4f}")
        
        # Save metrics locally
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        
    return history

# %%
# Execute training
history = train_model(model, criterion, optimizer, train_loader, val_loader, epochs=EPOCHS)
# Out:
# Epoch 1/50
# ------------------------------
# [Batch 20/92] Loss: 1.0866 | Batch Acc: 0.6250
# [Batch 40/92] Loss: 0.8044 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.7801 | Batch Acc: 0.7188
# [Batch 80/92] Loss: 0.6749 | Batch Acc: 0.7188
# Epoch 1 Summary - Train Loss: 0.8794 | Train Acc: 0.7142
# Validation Accuracy: 0.8747
#
# Epoch 2/50
# ------------------------------
# [Batch 20/92] Loss: 0.7289 | Batch Acc: 0.7812
# [Batch 40/92] Loss: 0.4777 | Batch Acc: 0.8125
# [Batch 60/92] Loss: 0.5536 | Batch Acc: 0.8125
# [Batch 80/92] Loss: 0.3553 | Batch Acc: 0.9062
# Epoch 2 Summary - Train Loss: 0.4723 | Train Acc: 0.8593
# Validation Accuracy: 0.8937
#
# Epoch 3/50
# ------------------------------
# [Batch 20/92] Loss: 0.3189 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.3166 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.3507 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.3413 | Batch Acc: 0.9062
# Epoch 3 Summary - Train Loss: 0.3963 | Train Acc: 0.8699
# Validation Accuracy: 0.8992
#
# Epoch 4/50
# ------------------------------
# [Batch 20/92] Loss: 0.5348 | Batch Acc: 0.7500
# [Batch 40/92] Loss: 0.3330 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3261 | Batch Acc: 0.8125
# [Batch 80/92] Loss: 0.3980 | Batch Acc: 0.8438
# Epoch 4 Summary - Train Loss: 0.3603 | Train Acc: 0.8777
# Validation Accuracy: 0.9087
#
# Epoch 5/50
# ------------------------------
# [Batch 20/92] Loss: 0.2980 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.3684 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3265 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.3112 | Batch Acc: 0.8750
# Epoch 5 Summary - Train Loss: 0.3370 | Train Acc: 0.8862
# Validation Accuracy: 0.9155
#
# Epoch 6/50
# ------------------------------
# [Batch 20/92] Loss: 0.4187 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1592 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2831 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.2837 | Batch Acc: 0.9062
# Epoch 6 Summary - Train Loss: 0.3092 | Train Acc: 0.8961
# Validation Accuracy: 0.9087
#
# Epoch 7/50
# ------------------------------
# [Batch 20/92] Loss: 0.1813 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2735 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2743 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.4374 | Batch Acc: 0.8750
# Epoch 7 Summary - Train Loss: 0.2921 | Train Acc: 0.9026
# Validation Accuracy: 0.9128
#
# Epoch 8/50
# ------------------------------
# [Batch 20/92] Loss: 0.2257 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.4065 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2613 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1678 | Batch Acc: 0.9375
# Epoch 8 Summary - Train Loss: 0.2887 | Train Acc: 0.8988
# Validation Accuracy: 0.9210
#
# Epoch 9/50
# ------------------------------
# [Batch 20/92] Loss: 0.1933 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.5459 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3463 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.1767 | Batch Acc: 0.9062
# Epoch 9 Summary - Train Loss: 0.2780 | Train Acc: 0.9091
# Validation Accuracy: 0.9210
#
# Epoch 10/50
# ------------------------------
# [Batch 20/92] Loss: 0.4323 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.2534 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2150 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.3132 | Batch Acc: 0.8438
# Epoch 10 Summary - Train Loss: 0.2663 | Train Acc: 0.9033
# Validation Accuracy: 0.9210
#
# Epoch 11/50
# ------------------------------
# [Batch 20/92] Loss: 0.1145 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.3126 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2081 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1379 | Batch Acc: 0.9688
# Epoch 11 Summary - Train Loss: 0.2679 | Train Acc: 0.9040
# Validation Accuracy: 0.9264
#
# Epoch 12/50
# ------------------------------
# [Batch 20/92] Loss: 0.0800 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.5251 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.1414 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1763 | Batch Acc: 0.9062
# Epoch 12 Summary - Train Loss: 0.2534 | Train Acc: 0.9159
# Validation Accuracy: 0.9183
#
# Epoch 13/50
# ------------------------------
# [Batch 20/92] Loss: 0.1292 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2876 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.3694 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.2574 | Batch Acc: 0.9062
# Epoch 13 Summary - Train Loss: 0.2389 | Train Acc: 0.9200
# Validation Accuracy: 0.9251
#
# Epoch 14/50
# ------------------------------
# [Batch 20/92] Loss: 0.1859 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.0317 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2666 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.2634 | Batch Acc: 0.9375
# Epoch 14 Summary - Train Loss: 0.2570 | Train Acc: 0.9063
# Validation Accuracy: 0.9237
#
# Epoch 15/50
# ------------------------------
# [Batch 20/92] Loss: 0.1469 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2080 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1565 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1485 | Batch Acc: 0.9375
# Epoch 15 Summary - Train Loss: 0.2258 | Train Acc: 0.9240
# Validation Accuracy: 0.9278
#
# Epoch 16/50
# ------------------------------
# [Batch 20/92] Loss: 0.2151 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2524 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2168 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2168 | Batch Acc: 0.9062
# Epoch 16 Summary - Train Loss: 0.2200 | Train Acc: 0.9251
# Validation Accuracy: 0.9264
#
# Epoch 17/50
# ------------------------------
# [Batch 20/92] Loss: 0.2537 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2446 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2260 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.0970 | Batch Acc: 0.9688
# Epoch 17 Summary - Train Loss: 0.2160 | Train Acc: 0.9230
# Validation Accuracy: 0.9278
#
# Epoch 18/50
# ------------------------------
# [Batch 20/92] Loss: 0.3209 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1473 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2434 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.3137 | Batch Acc: 0.8750
# Epoch 18 Summary - Train Loss: 0.2205 | Train Acc: 0.9210
# Validation Accuracy: 0.9183
#
# Epoch 19/50
# ------------------------------
# [Batch 20/92] Loss: 0.0857 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.4015 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.2402 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2495 | Batch Acc: 0.9688
# Epoch 19 Summary - Train Loss: 0.2166 | Train Acc: 0.9237
# Validation Accuracy: 0.9237
#
# Epoch 20/50
# ------------------------------
# [Batch 20/92] Loss: 0.1860 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.3214 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.1555 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2452 | Batch Acc: 0.8750
# Epoch 20 Summary - Train Loss: 0.2150 | Train Acc: 0.9244
# Validation Accuracy: 0.9251
#
# Epoch 21/50
# ------------------------------
# [Batch 20/92] Loss: 0.3989 | Batch Acc: 0.7812
# [Batch 40/92] Loss: 0.1897 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.2836 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1357 | Batch Acc: 0.9375
# Epoch 21 Summary - Train Loss: 0.2130 | Train Acc: 0.9223
# Validation Accuracy: 0.9278
#
# Epoch 22/50
# ------------------------------
# [Batch 20/92] Loss: 0.2790 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2966 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1179 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1605 | Batch Acc: 0.9375
# Epoch 22 Summary - Train Loss: 0.2128 | Train Acc: 0.9275
# Validation Accuracy: 0.9196
#
# Epoch 23/50
# ------------------------------
# [Batch 20/92] Loss: 0.1058 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1524 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.5805 | Batch Acc: 0.8125
# [Batch 80/92] Loss: 0.2433 | Batch Acc: 0.9062
# Epoch 23 Summary - Train Loss: 0.2143 | Train Acc: 0.9251
# Validation Accuracy: 0.9155
#
# Epoch 24/50
# ------------------------------
# [Batch 20/92] Loss: 0.1610 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1794 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1662 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1438 | Batch Acc: 0.9688
# Epoch 24 Summary - Train Loss: 0.1968 | Train Acc: 0.9370
# Validation Accuracy: 0.9346
#
# Epoch 25/50
# ------------------------------
# [Batch 20/92] Loss: 0.1630 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.0954 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0870 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.2013 | Batch Acc: 0.9688
# Epoch 25 Summary - Train Loss: 0.2036 | Train Acc: 0.9326
# Validation Accuracy: 0.9251
#
# Epoch 26/50
# ------------------------------
# [Batch 20/92] Loss: 0.1917 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.2581 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3566 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.3463 | Batch Acc: 0.8438
# Epoch 26 Summary - Train Loss: 0.2116 | Train Acc: 0.9200
# Validation Accuracy: 0.9278
#
# Epoch 27/50
# ------------------------------
# [Batch 20/92] Loss: 0.3586 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.3131 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3360 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1295 | Batch Acc: 0.9688
# Epoch 27 Summary - Train Loss: 0.1980 | Train Acc: 0.9305
# Validation Accuracy: 0.9264
#
# Epoch 28/50
# ------------------------------
# [Batch 20/92] Loss: 0.1379 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.2662 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1341 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1730 | Batch Acc: 0.9062
# Epoch 28 Summary - Train Loss: 0.1848 | Train Acc: 0.9356
# Validation Accuracy: 0.9237
#
# Epoch 29/50
# ------------------------------
# [Batch 20/92] Loss: 0.1009 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.4640 | Batch Acc: 0.8125
# [Batch 60/92] Loss: 0.4493 | Batch Acc: 0.8125
# [Batch 80/92] Loss: 0.1207 | Batch Acc: 1.0000
# Epoch 29 Summary - Train Loss: 0.1931 | Train Acc: 0.9326
# Validation Accuracy: 0.9183
#
# Epoch 30/50
# ------------------------------
# [Batch 20/92] Loss: 0.3273 | Batch Acc: 0.7812
# [Batch 40/92] Loss: 0.0391 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2165 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2436 | Batch Acc: 0.9375
# Epoch 30 Summary - Train Loss: 0.1916 | Train Acc: 0.9309
# Validation Accuracy: 0.9264
#
# Epoch 31/50
# ------------------------------
# [Batch 20/92] Loss: 0.2928 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.2660 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2123 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.2494 | Batch Acc: 0.8750
# Epoch 31 Summary - Train Loss: 0.1800 | Train Acc: 0.9373
# Validation Accuracy: 0.9305
#
# Epoch 32/50
# ------------------------------
# [Batch 20/92] Loss: 0.0940 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0253 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2385 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1206 | Batch Acc: 0.9688
# Epoch 32 Summary - Train Loss: 0.1928 | Train Acc: 0.9275
# Validation Accuracy: 0.9142
#
# Epoch 33/50
# ------------------------------
# [Batch 20/92] Loss: 0.2595 | Batch Acc: 0.8125
# [Batch 40/92] Loss: 0.2714 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1719 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1831 | Batch Acc: 0.9375
# Epoch 33 Summary - Train Loss: 0.1715 | Train Acc: 0.9428
# Validation Accuracy: 0.9223
#
# Epoch 34/50
# ------------------------------
# [Batch 20/92] Loss: 0.0812 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.3382 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1352 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1440 | Batch Acc: 0.9375
# Epoch 34 Summary - Train Loss: 0.2012 | Train Acc: 0.9319
# Validation Accuracy: 0.9223
#
# Epoch 35/50
# ------------------------------
# [Batch 20/92] Loss: 0.1167 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0686 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2201 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2887 | Batch Acc: 0.9062
# Epoch 35 Summary - Train Loss: 0.1784 | Train Acc: 0.9353
# Validation Accuracy: 0.9155
#
# Epoch 36/50
# ------------------------------
# [Batch 20/92] Loss: 0.1227 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.3084 | Batch Acc: 0.7812
# [Batch 60/92] Loss: 0.0453 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.3457 | Batch Acc: 0.8438
# Epoch 36 Summary - Train Loss: 0.1848 | Train Acc: 0.9298
# Validation Accuracy: 0.9210
#
# Epoch 37/50
# ------------------------------
# [Batch 20/92] Loss: 0.1415 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.2246 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1411 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.3409 | Batch Acc: 0.8125
# Epoch 37 Summary - Train Loss: 0.1818 | Train Acc: 0.9329
# Validation Accuracy: 0.9237
#
# Epoch 38/50
# ------------------------------
# [Batch 20/92] Loss: 0.2196 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1503 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1525 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1840 | Batch Acc: 0.9062
# Epoch 38 Summary - Train Loss: 0.1907 | Train Acc: 0.9295
# Validation Accuracy: 0.9155
#
# Epoch 39/50
# ------------------------------
# [Batch 20/92] Loss: 0.1675 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2920 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1380 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1041 | Batch Acc: 0.9688
# Epoch 39 Summary - Train Loss: 0.1853 | Train Acc: 0.9292
# Validation Accuracy: 0.9223
#
# Epoch 40/50
# ------------------------------
# [Batch 20/92] Loss: 0.2911 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1452 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.4280 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.2059 | Batch Acc: 0.9375
# Epoch 40 Summary - Train Loss: 0.1894 | Train Acc: 0.9315
# Validation Accuracy: 0.9237
#
# Epoch 41/50
# ------------------------------
# [Batch 20/92] Loss: 0.1064 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0281 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0974 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.2264 | Batch Acc: 0.9375
# Epoch 41 Summary - Train Loss: 0.1762 | Train Acc: 0.9387
# Validation Accuracy: 0.9264
#
# Epoch 42/50
# ------------------------------
# [Batch 20/92] Loss: 0.1078 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1219 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1974 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1317 | Batch Acc: 0.9375
# Epoch 42 Summary - Train Loss: 0.1766 | Train Acc: 0.9349
# Validation Accuracy: 0.9183
#
# Epoch 43/50
# ------------------------------
# [Batch 20/92] Loss: 0.1568 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.1633 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2787 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.2073 | Batch Acc: 0.9062
# Epoch 43 Summary - Train Loss: 0.1689 | Train Acc: 0.9418
# Validation Accuracy: 0.9155
#
# Epoch 44/50
# ------------------------------
# [Batch 20/92] Loss: 0.2101 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1725 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.2433 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1060 | Batch Acc: 0.9375
# Epoch 44 Summary - Train Loss: 0.1709 | Train Acc: 0.9373
# Validation Accuracy: 0.9237
#
# Epoch 45/50
# ------------------------------
# [Batch 20/92] Loss: 0.0897 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.3000 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.0303 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1331 | Batch Acc: 0.9688
# Epoch 45 Summary - Train Loss: 0.1621 | Train Acc: 0.9431
# Validation Accuracy: 0.9237
#
# Epoch 46/50
# ------------------------------
# [Batch 20/92] Loss: 0.3573 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.1597 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1978 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.2885 | Batch Acc: 0.9375
# Epoch 46 Summary - Train Loss: 0.1701 | Train Acc: 0.9384
# Validation Accuracy: 0.9114
#
# Epoch 47/50
# ------------------------------
# [Batch 20/92] Loss: 0.3061 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.0468 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0459 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.2728 | Batch Acc: 0.8750
# Epoch 47 Summary - Train Loss: 0.1775 | Train Acc: 0.9387
# Validation Accuracy: 0.9237
#
# Epoch 48/50
# ------------------------------
# [Batch 20/92] Loss: 0.1235 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1716 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.2727 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2145 | Batch Acc: 0.9062
# Epoch 48 Summary - Train Loss: 0.1886 | Train Acc: 0.9309
# Validation Accuracy: 0.9183
#
# Epoch 49/50
# ------------------------------
# [Batch 20/92] Loss: 0.3208 | Batch Acc: 0.8750
# [Batch 40/92] Loss: 0.1506 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2281 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1593 | Batch Acc: 0.9375
# Epoch 49 Summary - Train Loss: 0.1697 | Train Acc: 0.9404
# Validation Accuracy: 0.9251
#
# Epoch 50/50
# ------------------------------
# [Batch 20/92] Loss: 0.2344 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2056 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0868 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.2084 | Batch Acc: 0.9375
# Epoch 50 Summary - Train Loss: 0.1595 | Train Acc: 0.9407
# Validation Accuracy: 0.9210

# %%
import matplotlib.pyplot as plt

# Set aesthetic style
plt.style.use('seaborn-v0_8-whitegrid')
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot Accuracy History
axes[0].plot(history['train_acc'], label='Train Accuracy', color='#1f77b4', linewidth=2)
axes[0].plot(history['val_acc'], label='Validation Accuracy', color='#ff7f0e', linewidth=2)
axes[0].set_title('SqueezeNet Accuracy over 50 Epochs', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot Loss History
axes[1].plot(history['train_loss'], label='Train Loss', color='#d62728', linewidth=2)
axes[1].set_title('SqueezeNet Loss over 50 Epochs', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save Model Checkpoint
save_path = '/kaggle/working/squeezenet_5flowers_model.pth'
torch.save(model.state_dict(), save_path)
print(f"Model weights successfully saved to {save_path}")
# Out:
# Model weights successfully saved to /kaggle/working/squeezenet_5flowers_model.pth

# %%
import random
import matplotlib.pyplot as plt

# 1. Retrieve the list of flower class names 
class_names = full_dataset.classes

# %%
# 2. Lock the model into evaluation mode
model.eval()
# Out:
# DataParallel(
#   (module): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Linear(in_features=1024, out_features=5, bias=True)
#   )
# )

# %%
# 3. Select a random image from the validation set
random_idx = random.randint(0, len(val_dataset) - 1)
image_tensor, actual_label_idx = val_dataset[random_idx]

# %%
# 4. Add a batch dimension: (C, H, W) -> (1, C, H, W) and move to GPU
image_batch = image_tensor.unsqueeze(0).to(device)

# %%
# 5. Perform the forward pass (inference)
with torch.no_grad():
    output = model(image_batch)
    # Extract the index of the highest logit score
    _, predicted_idx = torch.max(output, 1)

# %%
# Map the numerical indices back to the string names
actual_flower = class_names[actual_label_idx]
predicted_flower = class_names[predicted_idx.item()]

# %%
# 6. Un-normalize the image for human viewing
# Move tensor to CPU, then convert to a NumPy array
image_display = image_tensor.permute(1, 2, 0).cpu().numpy()

# %%
# Apply the inverse of the ImageNet normalization math
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
image_display = std * image_display + mean
image_display = image_display.clip(0, 1) # Force pixel values into valid [0, 1] range

# %%
# 7. Plot the result
plt.figure(figsize=(6, 6))
plt.imshow(image_display)

# Title is green if correct, red if the model made a mistake
title_color = "#2ca02c" if actual_flower == predicted_flower else "#d62728"
plt.title(f"Actual: {actual_flower} | Predicted: {predicted_flower}", color=title_color, fontsize=14, fontweight='bold')
plt.axis('off')
plt.show()
