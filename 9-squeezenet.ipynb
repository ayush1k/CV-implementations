# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# 1. Download the dataset archive quietly
# !wget -q https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz

# 2. Untar the archive directly into Kaggle's working directory
# !tar -xzf flower_photos.tgz -C /kaggle/working/

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torchvision.models import squeezenet1_1, SqueezeNet1_1_Weights
from torch.utils.data import DataLoader, random_split
import os

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 0.001
INPUT_SIZE = 224

# Set compute device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Primary compute device: {device}")
# Out:
# Primary compute device: cuda

# %%
# Define separate transformation pipelines for Training and Validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.RandomHorizontalFlip(),  # Augmentation to prevent overfitting
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((INPUT_SIZE, INPUT_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# 1. Load full raw dataset
data_dir = "/kaggle/working/flower_photos"
full_dataset = datasets.ImageFolder(root=data_dir, transform=data_transforms['train'])

# %%
# 2. Perform 80/20 train/validation split
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# %%
# 3. Override validation subset transform so validation images aren't randomly flipped
val_dataset.dataset.transform = data_transforms['val']

# %%
# 4. Construct DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# %%
print(f"Training set: {len(train_dataset)} images | Validation set: {len(val_dataset)} images")
# Out:
# Training set: 2936 images | Validation set: 734 images

# %%
# 1. Load pretrained SqueezeNet 1.1
model = squeezenet1_1(weights=SqueezeNet1_1_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
# 100%|██████████| 4.73M/4.73M [00:00<00:00, 176MB/s]

# %%
# 2. Freeze all foundational layers
for param in model.parameters():
    param.requires_grad = False

# %%
# 3. Modify SqueezeNet's unique classifier block
# Index 1 of model.classifier is a Conv2d layer expecting 512 input channels
model.classifier[1] = nn.Conv2d(in_channels=512, out_channels=5, kernel_size=1)

# %%
# 4. Unfreeze parameters for ONLY the new Conv2d classification layer
for param in model.classifier[1].parameters():
    param.requires_grad = True

# %%
# 5. Enable Multi-GPU training across both Kaggle T4 GPUs
if torch.cuda.device_count() > 1:
    print(f"Detected {torch.cuda.device_count()} GPUs! Wrapping model in DataParallel...")
    model = nn.DataParallel(model)
# Out:
# Detected 2 GPUs! Wrapping model in DataParallel...

# %%
# Move the model to GPU memory
model = model.to(device)

# %%
# 6. Define Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, epochs):
    # Local history dictionary to log metrics
    history = {'train_loss': [], 'train_acc': [], 'val_acc': []}
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        print("-" * 30)
        
        # ================= TRAINING PHASE =================
        model.train()  # Enables Dropout layers in training mode
        train_correct = 0
        train_total = 0
        running_loss = 0.0

        for i, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()            # Clear old gradients
            outputs = model(images)          # Forward pass
            loss = criterion(outputs, labels) # Calculate Cross-Entropy Loss
            loss.backward()                  # Backward pass (compute gradients)
            optimizer.step()                 # Update layer weights

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1) # Extract class prediction with highest logit
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            # Print status every 20 batches
            if (i + 1) % 20 == 0:
                batch_acc = (preds == labels).sum().item() / labels.size(0)
                print(f"[Batch {i+1}/{len(train_loader)}] Loss: {loss.item():.4f} | Batch Acc: {batch_acc:.4f}")

        train_acc = train_correct / train_total
        avg_train_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1} Summary - Train Loss: {avg_train_loss:.4f} | Train Acc: {train_acc:.4f}")

        # ================= VALIDATION PHASE =================
        model.eval()  # Disables Dropout for evaluation
        val_correct = 0
        val_total = 0
        
        with torch.no_grad():  # Disable gradient calculation to conserve VRAM
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total
        print(f"Validation Accuracy: {val_acc:.4f}")
        
        # Save metrics locally
        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        
    return history

# %%
# Execute training
history = train_model(model, criterion, optimizer, train_loader, val_loader, epochs=EPOCHS)
# Out:
# Epoch 1/50
# ------------------------------
# [Batch 20/92] Loss: 0.8072 | Batch Acc: 0.7188
# [Batch 40/92] Loss: 0.7067 | Batch Acc: 0.6875
# [Batch 60/92] Loss: 0.4238 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.3669 | Batch Acc: 0.8438
# Epoch 1 Summary - Train Loss: 0.7373 | Train Acc: 0.7241
# Validation Accuracy: 0.8488
#
# Epoch 2/50
# ------------------------------
# [Batch 20/92] Loss: 0.4935 | Batch Acc: 0.8125
# [Batch 40/92] Loss: 0.3872 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.3917 | Batch Acc: 0.7812
# [Batch 80/92] Loss: 0.4972 | Batch Acc: 0.8750
# Epoch 2 Summary - Train Loss: 0.3895 | Train Acc: 0.8610
# Validation Accuracy: 0.8665
#
# Epoch 3/50
# ------------------------------
# [Batch 20/92] Loss: 0.1507 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1344 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.3732 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.3511 | Batch Acc: 0.8750
# Epoch 3 Summary - Train Loss: 0.3241 | Train Acc: 0.8808
# Validation Accuracy: 0.8638
#
# Epoch 4/50
# ------------------------------
# [Batch 20/92] Loss: 0.1761 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.3046 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.5173 | Batch Acc: 0.8438
# [Batch 80/92] Loss: 0.1667 | Batch Acc: 0.9062
# Epoch 4 Summary - Train Loss: 0.2817 | Train Acc: 0.8988
# Validation Accuracy: 0.8910
#
# Epoch 5/50
# ------------------------------
# [Batch 20/92] Loss: 0.1947 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.2898 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.1006 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1979 | Batch Acc: 0.8750
# Epoch 5 Summary - Train Loss: 0.2639 | Train Acc: 0.9063
# Validation Accuracy: 0.8801
#
# Epoch 6/50
# ------------------------------
# [Batch 20/92] Loss: 0.1924 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.0703 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2121 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.4264 | Batch Acc: 0.8750
# Epoch 6 Summary - Train Loss: 0.2430 | Train Acc: 0.9135
# Validation Accuracy: 0.8856
#
# Epoch 7/50
# ------------------------------
# [Batch 20/92] Loss: 0.1154 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2389 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2568 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1852 | Batch Acc: 0.9688
# Epoch 7 Summary - Train Loss: 0.2119 | Train Acc: 0.9285
# Validation Accuracy: 0.8910
#
# Epoch 8/50
# ------------------------------
# [Batch 20/92] Loss: 0.1469 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1250 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2071 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1375 | Batch Acc: 0.9688
# Epoch 8 Summary - Train Loss: 0.1986 | Train Acc: 0.9319
# Validation Accuracy: 0.8992
#
# Epoch 9/50
# ------------------------------
# [Batch 20/92] Loss: 0.1147 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0695 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.3194 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1438 | Batch Acc: 0.9375
# Epoch 9 Summary - Train Loss: 0.2027 | Train Acc: 0.9298
# Validation Accuracy: 0.8910
#
# Epoch 10/50
# ------------------------------
# [Batch 20/92] Loss: 0.0993 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.4032 | Batch Acc: 0.8438
# [Batch 60/92] Loss: 0.3289 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1593 | Batch Acc: 0.9375
# Epoch 10 Summary - Train Loss: 0.1844 | Train Acc: 0.9370
# Validation Accuracy: 0.9005
#
# Epoch 11/50
# ------------------------------
# [Batch 20/92] Loss: 0.0863 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1188 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.2853 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1011 | Batch Acc: 0.9688
# Epoch 11 Summary - Train Loss: 0.1745 | Train Acc: 0.9411
# Validation Accuracy: 0.9060
#
# Epoch 12/50
# ------------------------------
# [Batch 20/92] Loss: 0.1045 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2289 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1353 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0885 | Batch Acc: 1.0000
# Epoch 12 Summary - Train Loss: 0.1737 | Train Acc: 0.9438
# Validation Accuracy: 0.8992
#
# Epoch 13/50
# ------------------------------
# [Batch 20/92] Loss: 0.1469 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0661 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.2259 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2004 | Batch Acc: 0.9062
# Epoch 13 Summary - Train Loss: 0.1680 | Train Acc: 0.9421
# Validation Accuracy: 0.8978
#
# Epoch 14/50
# ------------------------------
# [Batch 20/92] Loss: 0.1901 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.2254 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1122 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1174 | Batch Acc: 0.9375
# Epoch 14 Summary - Train Loss: 0.1585 | Train Acc: 0.9482
# Validation Accuracy: 0.8883
#
# Epoch 15/50
# ------------------------------
# [Batch 20/92] Loss: 0.1448 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1678 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.2447 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1409 | Batch Acc: 0.9375
# Epoch 15 Summary - Train Loss: 0.1565 | Train Acc: 0.9431
# Validation Accuracy: 0.8978
#
# Epoch 16/50
# ------------------------------
# [Batch 20/92] Loss: 0.0494 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.2470 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2078 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.2360 | Batch Acc: 0.9375
# Epoch 16 Summary - Train Loss: 0.1549 | Train Acc: 0.9424
# Validation Accuracy: 0.8992
#
# Epoch 17/50
# ------------------------------
# [Batch 20/92] Loss: 0.2007 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.2460 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.1383 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.2798 | Batch Acc: 0.8438
# Epoch 17 Summary - Train Loss: 0.1481 | Train Acc: 0.9540
# Validation Accuracy: 0.8828
#
# Epoch 18/50
# ------------------------------
# [Batch 20/92] Loss: 0.1208 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1213 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1042 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.2454 | Batch Acc: 0.9062
# Epoch 18 Summary - Train Loss: 0.1398 | Train Acc: 0.9520
# Validation Accuracy: 0.8937
#
# Epoch 19/50
# ------------------------------
# [Batch 20/92] Loss: 0.0267 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0449 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1381 | Batch Acc: 0.9062
# [Batch 80/92] Loss: 0.1278 | Batch Acc: 0.9688
# Epoch 19 Summary - Train Loss: 0.1338 | Train Acc: 0.9578
# Validation Accuracy: 0.8910
#
# Epoch 20/50
# ------------------------------
# [Batch 20/92] Loss: 0.0246 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.3206 | Batch Acc: 0.8750
# [Batch 60/92] Loss: 0.0563 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.1084 | Batch Acc: 0.9688
# Epoch 20 Summary - Train Loss: 0.1286 | Train Acc: 0.9557
# Validation Accuracy: 0.8910
#
# Epoch 21/50
# ------------------------------
# [Batch 20/92] Loss: 0.0399 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1088 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1686 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1667 | Batch Acc: 0.9375
# Epoch 21 Summary - Train Loss: 0.1280 | Train Acc: 0.9591
# Validation Accuracy: 0.8842
#
# Epoch 22/50
# ------------------------------
# [Batch 20/92] Loss: 0.1470 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1098 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1348 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1120 | Batch Acc: 1.0000
# Epoch 22 Summary - Train Loss: 0.1343 | Train Acc: 0.9554
# Validation Accuracy: 0.8842
#
# Epoch 23/50
# ------------------------------
# [Batch 20/92] Loss: 0.0361 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0822 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0801 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0769 | Batch Acc: 0.9688
# Epoch 23 Summary - Train Loss: 0.1269 | Train Acc: 0.9574
# Validation Accuracy: 0.8787
#
# Epoch 24/50
# ------------------------------
# [Batch 20/92] Loss: 0.0762 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0501 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1378 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1092 | Batch Acc: 0.9375
# Epoch 24 Summary - Train Loss: 0.1137 | Train Acc: 0.9629
# Validation Accuracy: 0.8883
#
# Epoch 25/50
# ------------------------------
# [Batch 20/92] Loss: 0.0517 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1177 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.1514 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1264 | Batch Acc: 0.9688
# Epoch 25 Summary - Train Loss: 0.1281 | Train Acc: 0.9567
# Validation Accuracy: 0.8760
#
# Epoch 26/50
# ------------------------------
# [Batch 20/92] Loss: 0.0703 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0950 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0572 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0562 | Batch Acc: 0.9688
# Epoch 26 Summary - Train Loss: 0.1151 | Train Acc: 0.9646
# Validation Accuracy: 0.8828
#
# Epoch 27/50
# ------------------------------
# [Batch 20/92] Loss: 0.0938 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0309 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1785 | Batch Acc: 0.8750
# [Batch 80/92] Loss: 0.1259 | Batch Acc: 0.9688
# Epoch 27 Summary - Train Loss: 0.1156 | Train Acc: 0.9588
# Validation Accuracy: 0.8856
#
# Epoch 28/50
# ------------------------------
# [Batch 20/92] Loss: 0.0734 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0465 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0583 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.2209 | Batch Acc: 0.9062
# Epoch 28 Summary - Train Loss: 0.1136 | Train Acc: 0.9595
# Validation Accuracy: 0.8815
#
# Epoch 29/50
# ------------------------------
# [Batch 20/92] Loss: 0.0934 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0571 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0190 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0708 | Batch Acc: 0.9688
# Epoch 29 Summary - Train Loss: 0.1171 | Train Acc: 0.9598
# Validation Accuracy: 0.8815
#
# Epoch 30/50
# ------------------------------
# [Batch 20/92] Loss: 0.1079 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0954 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0548 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0263 | Batch Acc: 1.0000
# Epoch 30 Summary - Train Loss: 0.1092 | Train Acc: 0.9659
# Validation Accuracy: 0.8815
#
# Epoch 31/50
# ------------------------------
# [Batch 20/92] Loss: 0.0561 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0702 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.0652 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0678 | Batch Acc: 1.0000
# Epoch 31 Summary - Train Loss: 0.1172 | Train Acc: 0.9622
# Validation Accuracy: 0.8842
#
# Epoch 32/50
# ------------------------------
# [Batch 20/92] Loss: 0.0988 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1691 | Batch Acc: 0.9062
# [Batch 60/92] Loss: 0.2957 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.2268 | Batch Acc: 0.9688
# Epoch 32 Summary - Train Loss: 0.1097 | Train Acc: 0.9629
# Validation Accuracy: 0.8815
#
# Epoch 33/50
# ------------------------------
# [Batch 20/92] Loss: 0.0731 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.2964 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0315 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.2176 | Batch Acc: 0.9375
# Epoch 33 Summary - Train Loss: 0.1064 | Train Acc: 0.9649
# Validation Accuracy: 0.8869
#
# Epoch 34/50
# ------------------------------
# [Batch 20/92] Loss: 0.0749 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0348 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1580 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0550 | Batch Acc: 0.9688
# Epoch 34 Summary - Train Loss: 0.1010 | Train Acc: 0.9693
# Validation Accuracy: 0.8869
#
# Epoch 35/50
# ------------------------------
# [Batch 20/92] Loss: 0.0251 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.1292 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0400 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1294 | Batch Acc: 0.9688
# Epoch 35 Summary - Train Loss: 0.0968 | Train Acc: 0.9697
# Validation Accuracy: 0.8896
#
# Epoch 36/50
# ------------------------------
# [Batch 20/92] Loss: 0.0611 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1343 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.1199 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0611 | Batch Acc: 1.0000
# Epoch 36 Summary - Train Loss: 0.0933 | Train Acc: 0.9680
# Validation Accuracy: 0.8910
#
# Epoch 37/50
# ------------------------------
# [Batch 20/92] Loss: 0.0277 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0620 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1281 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0577 | Batch Acc: 1.0000
# Epoch 37 Summary - Train Loss: 0.1040 | Train Acc: 0.9670
# Validation Accuracy: 0.8869
#
# Epoch 38/50
# ------------------------------
# [Batch 20/92] Loss: 0.1149 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.0624 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1082 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0774 | Batch Acc: 0.9688
# Epoch 38 Summary - Train Loss: 0.1035 | Train Acc: 0.9653
# Validation Accuracy: 0.8856
#
# Epoch 39/50
# ------------------------------
# [Batch 20/92] Loss: 0.0657 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0669 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1027 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.1661 | Batch Acc: 0.9375
# Epoch 39 Summary - Train Loss: 0.0892 | Train Acc: 0.9738
# Validation Accuracy: 0.8747
#
# Epoch 40/50
# ------------------------------
# [Batch 20/92] Loss: 0.1766 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.0833 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1200 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.3053 | Batch Acc: 0.8750
# Epoch 40 Summary - Train Loss: 0.1041 | Train Acc: 0.9646
# Validation Accuracy: 0.8760
#
# Epoch 41/50
# ------------------------------
# [Batch 20/92] Loss: 0.2914 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1087 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0827 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.3070 | Batch Acc: 0.9375
# Epoch 41 Summary - Train Loss: 0.0922 | Train Acc: 0.9710
# Validation Accuracy: 0.8787
#
# Epoch 42/50
# ------------------------------
# [Batch 20/92] Loss: 0.0369 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0422 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1979 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.1426 | Batch Acc: 0.9375
# Epoch 42 Summary - Train Loss: 0.0901 | Train Acc: 0.9704
# Validation Accuracy: 0.8842
#
# Epoch 43/50
# ------------------------------
# [Batch 20/92] Loss: 0.0139 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0857 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0750 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0389 | Batch Acc: 1.0000
# Epoch 43 Summary - Train Loss: 0.0915 | Train Acc: 0.9693
# Validation Accuracy: 0.8692
#
# Epoch 44/50
# ------------------------------
# [Batch 20/92] Loss: 0.0994 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.0331 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1919 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0686 | Batch Acc: 0.9688
# Epoch 44 Summary - Train Loss: 0.0923 | Train Acc: 0.9659
# Validation Accuracy: 0.8828
#
# Epoch 45/50
# ------------------------------
# [Batch 20/92] Loss: 0.1971 | Batch Acc: 0.9375
# [Batch 40/92] Loss: 0.1101 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0222 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0726 | Batch Acc: 1.0000
# Epoch 45 Summary - Train Loss: 0.0917 | Train Acc: 0.9687
# Validation Accuracy: 0.8801
#
# Epoch 46/50
# ------------------------------
# [Batch 20/92] Loss: 0.0464 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1367 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.1255 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0201 | Batch Acc: 1.0000
# Epoch 46 Summary - Train Loss: 0.0902 | Train Acc: 0.9690
# Validation Accuracy: 0.8815
#
# Epoch 47/50
# ------------------------------
# [Batch 20/92] Loss: 0.1780 | Batch Acc: 0.9062
# [Batch 40/92] Loss: 0.1030 | Batch Acc: 0.9375
# [Batch 60/92] Loss: 0.0939 | Batch Acc: 0.9375
# [Batch 80/92] Loss: 0.0588 | Batch Acc: 1.0000
# Epoch 47 Summary - Train Loss: 0.0865 | Train Acc: 0.9683
# Validation Accuracy: 0.8883
#
# Epoch 48/50
# ------------------------------
# [Batch 20/92] Loss: 0.0386 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0587 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0380 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0348 | Batch Acc: 1.0000
# Epoch 48 Summary - Train Loss: 0.0906 | Train Acc: 0.9673
# Validation Accuracy: 0.8815
#
# Epoch 49/50
# ------------------------------
# [Batch 20/92] Loss: 0.0775 | Batch Acc: 0.9688
# [Batch 40/92] Loss: 0.1088 | Batch Acc: 0.9688
# [Batch 60/92] Loss: 0.0153 | Batch Acc: 1.0000
# [Batch 80/92] Loss: 0.0876 | Batch Acc: 0.9688
# Epoch 49 Summary - Train Loss: 0.0890 | Train Acc: 0.9724
# Validation Accuracy: 0.8787
#
# Epoch 50/50
# ------------------------------
# [Batch 20/92] Loss: 0.0854 | Batch Acc: 1.0000
# [Batch 40/92] Loss: 0.0555 | Batch Acc: 1.0000
# [Batch 60/92] Loss: 0.1043 | Batch Acc: 0.9688
# [Batch 80/92] Loss: 0.0530 | Batch Acc: 1.0000
# Epoch 50 Summary - Train Loss: 0.0897 | Train Acc: 0.9697
# Validation Accuracy: 0.8760

# %%
import matplotlib.pyplot as plt

# Set aesthetic style
plt.style.use('seaborn-v0_8-whitegrid')
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot Accuracy History
axes[0].plot(history['train_acc'], label='Train Accuracy', color='#1f77b4', linewidth=2)
axes[0].plot(history['val_acc'], label='Validation Accuracy', color='#ff7f0e', linewidth=2)
axes[0].set_title('SqueezeNet Accuracy over 50 Epochs', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

# Plot Loss History
axes[1].plot(history['train_loss'], label='Train Loss', color='#d62728', linewidth=2)
axes[1].set_title('SqueezeNet Loss over 50 Epochs', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Save Model Checkpoint
save_path = '/kaggle/working/squeezenet_5flowers_model.pth'
torch.save(model.state_dict(), save_path)
print(f"Model weights successfully saved to {save_path}")
# Out:
# Model weights successfully saved to /kaggle/working/squeezenet_5flowers_model.pth

# %%
import random
import matplotlib.pyplot as plt

# 1. Retrieve the list of flower class names 
class_names = full_dataset.classes

# %%
# 2. Lock the model into evaluation mode
model.eval()
# Out:
# DataParallel(
#   (module): SqueezeNet(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (3): Fire(
#         (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (4): Fire(
#         (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (6): Fire(
#         (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (7): Fire(
#         (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (9): Fire(
#         (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (10): Fire(
#         (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (11): Fire(
#         (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#       (12): Fire(
#         (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#         (squeeze_activation): ReLU(inplace=True)
#         (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (expand1x1_activation): ReLU(inplace=True)
#         (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (expand3x3_activation): ReLU(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.5, inplace=False)
#       (1): Conv2d(512, 5, kernel_size=(1, 1), stride=(1, 1))
#       (2): ReLU(inplace=True)
#       (3): AdaptiveAvgPool2d(output_size=(1, 1))
#     )
#   )
# )

# %%
# 3. Select a random image from the validation set
random_idx = random.randint(0, len(val_dataset) - 1)
image_tensor, actual_label_idx = val_dataset[random_idx]

# %%
# 4. Add a batch dimension: (C, H, W) -> (1, C, H, W) and move to GPU
image_batch = image_tensor.unsqueeze(0).to(device)

# %%
# 5. Perform the forward pass (inference)
with torch.no_grad():
    output = model(image_batch)
    # Extract the index of the highest logit score
    _, predicted_idx = torch.max(output, 1)

# %%
# Map the numerical indices back to the string names
actual_flower = class_names[actual_label_idx]
predicted_flower = class_names[predicted_idx.item()]

# %%
# 6. Un-normalize the image for human viewing
# Move tensor to CPU, then convert to a NumPy array
image_display = image_tensor.permute(1, 2, 0).cpu().numpy()

# %%
# Apply the inverse of the ImageNet normalization math
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
image_display = std * image_display + mean
image_display = image_display.clip(0, 1) # Force pixel values into valid [0, 1] range

# %%
# 7. Plot the result
plt.figure(figsize=(6, 6))
plt.imshow(image_display)

# Title is green if correct, red if the model made a mistake
title_color = "#2ca02c" if actual_flower == predicted_flower else "#d62728"
plt.title(f"Actual: {actual_flower} | Predicted: {predicted_flower}", color=title_color, fontsize=14, fontweight='bold')
plt.axis('off')
plt.show()
